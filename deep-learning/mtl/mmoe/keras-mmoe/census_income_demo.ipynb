# %% [markdown]
# # MMoE demo with census income data

# %%
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import VarianceScaling
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import roc_auc_score
from model import MMoE
from typing import *


SEED = 1
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## 1.数据处理

# %%
column_names = ['age', 'class_worker', 'det_ind_code', 'det_occ_code', 'education', 'wage_per_hour', 'hs_college',
                'marital_stat', 'major_ind_code', 'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member',
                'unemp_reason', 'full_or_part_emp', 'capital_gains', 'capital_losses', 'stock_dividends',
                'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat', 'det_hh_summ',
                'instance_weight', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                'num_emp', 'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                'own_or_self', 'vet_question', 'vet_benefits', 'weeks_worked', 'year', 'income_50k']

categorical_columns = ['class_worker', 'det_ind_code', 'det_occ_code', 'education', 'hs_college', 'major_ind_code',
                       'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member', 'unemp_reason',
                       'full_or_part_emp', 'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat',
                       'det_hh_summ', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                       'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                       'vet_question']

label_columns = ["marital_stat", "income_50k"]

train_df = pd.read_csv("data/census-income.data.gz", header=None, names=column_names)
other_df = pd.read_csv("data/census-income.test.gz", header=None, names=column_names)  # will split into eval & test later
print("Train: ", len(train_df))
print("Other: ", len(other_df))
total_df = pd.concat([train_df, other_df], axis=0, ignore_index=True)
train_df[:5]
# Out:
# Train:  199523
# Other:  99762
#    age                     class_worker  det_ind_code  det_occ_code  \
# 0   73                  Not in universe             0             0
# 1   58   Self-employed-not incorporated             4            34
# 2   18                  Not in universe             0             0
# 3    9                  Not in universe             0             0
# 4   10                  Not in universe             0             0
#
#                      education  wage_per_hour        hs_college  \
# 0         High school graduate              0   Not in universe
# 1   Some college but no degree              0   Not in universe
# 2                   10th grade              0       High school
# 3                     Children              0   Not in universe
# 4                     Children              0   Not in universe
#
#      marital_stat                major_ind_code  \
# 0         Widowed   Not in universe or children
# 1        Divorced                  Construction
# 2   Never married   Not in universe or children
# 3   Never married   Not in universe or children
# 4   Never married   Not in universe or children
#
#                          major_occ_code  ...  country_father  country_mother  \
# 0                       Not in universe  ...   United-States   United-States
# 1   Precision production craft & repair  ...   United-States   United-States
# 2                       Not in universe  ...         Vietnam         Vietnam
# 3                       Not in universe  ...   United-States   United-States
# 4                       Not in universe  ...   United-States   United-States
#
#      country_self                           citizenship own_or_self  \
# 0   United-States     Native- Born in the United States           0
# 1   United-States     Native- Born in the United States           0
# 2         Vietnam   Foreign born- Not a citizen of U S            0
# 3   United-States     Native- Born in the United States           0
# 4   United-States     Native- Born in the United States           0
#
#        vet_question  vet_benefits  weeks_worked  year income_50k
# 0   Not in universe             2             0    95   - 50000.
# 1   Not in universe             2            52    94   - 50000.
# 2   Not in universe             2             0    95   - 50000.
# 3   Not in universe             0             0    94   - 50000.
# 4   Not in universe             0             0    94   - 50000.
#
# [5 rows x 42 columns]

# %%
# one-hot encoding categorical columns
X = pd.get_dummies(total_df.drop(columns=label_columns, axis=1), columns=categorical_columns)
# categorical-encoding for labels
income_Y = pd.get_dummies(total_df["income_50k"]) 
marital_Y = pd.get_dummies((total_df["marital_stat"] == ' Never married').astype(int))  # 原本是多类别，转为2分类任务

train_X, other_X = X[:len(train_df)], X[len(train_df):]
train_income_Y, other_income_Y = income_Y[:len(train_df)], income_Y[len(train_df):]
train_marital_Y, other_marital_Y = marital_Y[:len(train_df)], marital_Y[len(train_df):]

# split other into eval & test
val_indices = other_X.sample(frac=0.5, replace=False, random_state=SEED).index
test_indices = list(set(other_X.index) - set(val_indices))

val_X, test_X = other_X.loc[val_indices], other_X.loc[test_indices]
val_income_Y, test_income_Y = other_income_Y.loc[val_indices], other_income_Y.loc[test_indices]
val_marital_Y, test_marital_Y = other_marital_Y.loc[val_indices], other_marital_Y.loc[test_indices]

# combine labels, keep the sequence order of labels: ["income", "marital"]
task_classes = {"income": income_Y.shape[1], "marital": marital_Y.shape[1]}
task_names = ["income", "marital"]

train_labels = {"income": train_income_Y, "marital": train_marital_Y}
val_labels = {"income": val_income_Y, "marital": val_marital_Y}
test_labels = {"income": test_income_Y, "marital": test_marital_Y}

# %% [markdown]
# ## 2. 模型构造

# %%
num_features = train_X.shape[1]
print(num_features)
# Out:
# 499

# %%
input_layer = Input(shape=(num_features,))
mmoe_layers = MMoE(units=4, n_experts=4, n_tasks=2)(input_layer)

output_layers = {}
for i, task_layer in enumerate(mmoe_layers):
    task_name = task_names[i]
    tower_layer = Dense(units=8, activation="relu", kernel_initializer="VarianceScaling")(task_layer)
    output_layer = Dense(units=task_classes[task_name], name=task_name, activation="softmax", kernel_initializer="VarianceScaling")(tower_layer)
    output_layers[task_name] = output_layer

model = Model(inputs=[input_layer], outputs=output_layers)
model.compile(loss={'income': 'binary_crossentropy', 'marital': 'binary_crossentropy'}, 
              optimizer=Adam(), metrics=["accuracy"])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 499)]        0
# __________________________________________________________________________________________________
# m_mo_e_1 (MMoE)                 [(None, 4), (None, 4 12000       input_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            40          m_mo_e_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            40          m_mo_e_1[0][1]
# __________________________________________________________________________________________________
# income (Dense)                  (None, 2)            18          dense_1[0][0]
# __________________________________________________________________________________________________
# marital (Dense)                 (None, 2)            18          dense_2[0][0]
# ==================================================================================================
# Total params: 12,116
# Trainable params: 12,116
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3. 训练

# %%
class ROCCallback(Callback):
    
    def __init__(self, training_data, validation_data, test_data):
        super(ROCCallback, self).__init__()
        self.train_X, self.train_Y = training_data
        self.val_X, self.val_Y = validation_data
        self.test_X, self.test_Y = test_data
    
    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        train_pred = self.model.predict(self.train_X)
        val_pred = self.model.predict(self.val_X)
        test_pred = self.model.predict(self.test_X)

        # Iterate through each task and output their ROC-AUC across different datasets
        for output_name in self.model.output_names:
            train_auc = roc_auc_score(self.train_Y[output_name], train_pred[output_name])
            val_auc = roc_auc_score(self.val_Y[output_name], val_pred[output_name])
            test_auc = roc_auc_score(self.test_Y[output_name], test_pred[output_name])
            print(f"{output_name}-AUC: Train-{train_auc:.4f}, Eval-{val_auc:.4f}, Test-{test_auc:.4f}")

        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
auc_callback = ROCCallback(training_data=(train_X, train_labels), 
                           validation_data=(val_X, val_labels), 
                           test_data=(test_X, test_labels))

model.fit(x=train_X, y=train_labels, validation_data=(val_X, val_labels), callbacks=[auc_callback], epochs=100)
# Out:
# Epoch 1/100
# 6236/6236 [==============================] - 8s 1ms/step - loss: 0.3841 - income_loss: 0.2329 - marital_loss: 0.1512 - income_accuracy: 0.9379 - marital_accuracy: 0.9424 - val_loss: 0.3567 - val_income_loss: 0.2329 - val_marital_loss: 0.1237 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9494
# income-AUC: Train-0.5015, Eval-0.5009, Test-0.5016
# marital-AUC: Train-0.9890, Eval-0.9890, Test-0.9887
# Epoch 2/100
# 6236/6236 [==============================] - 8s 1ms/step - loss: 0.3529 - income_loss: 0.2231 - marital_loss: 0.1299 - income_accuracy: 0.9379 - marital_accuracy: 0.9461 - val_loss: 0.3478 - val_income_loss: 0.2169 - val_marital_loss: 0.1309 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9418
# income-AUC: Train-0.6171, Eval-0.6216, Test-0.6259
# marital-AUC: Train-0.9904, Eval-0.9904, Test-0.9900
# Epoch 3/100
# 6236/6236 [==============================] - 8s 1ms/step - loss: 0.3066 - income_loss: 0.1826 - marital_loss: 0.1240 - income_accuracy: 0.9379 - marital_accuracy: 0.9493 - val_loss: 0.2793 - val_income_loss: 0.1552 - val_marital_loss: 0.1240 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9473
# income-AUC: Train-0.8895, Eval-0.8958, Test-0.8912
# marital-AUC: Train-0.9904, Eval-0.9906, Test-0.9902
# Epoch 4/100
# 6236/6236 [==============================] - 8s 1ms/step - loss: 0.2908 - income_loss: 0.1725 - marital_loss: 0.1183 - income_accuracy: 0.9379 - marital_accuracy: 0.9499 - val_loss: 0.2943 - val_income_loss: 0.1824 - val_marital_loss: 0.1119 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9541
# income-AUC: Train-0.8005, Eval-0.8077, Test-0.8080
# marital-AUC: Train-0.9913, Eval-0.9913, Test-0.9908
# Epoch 5/100
# 6236/6236 [==============================] - 9s 1ms/step - loss: 0.2768 - income_loss: 0.1609 - marital_loss: 0.1159 - income_accuracy: 0.9379 - marital_accuracy: 0.9509 - val_loss: 0.2895 - val_income_loss: 0.1783 - val_marital_loss: 0.1111 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.9546
# income-AUC: Train-0.8026, Eval-0.8069, Test-0.8070
# marital-AUC: Train-0.9917, Eval-0.9915, Test-0.9912
# Epoch 6/100
# 6236/6236 [==============================] - 9s 1ms/step - loss: 0.2719 - income_loss: 0.1596 - marital_loss: 0.1123 - income_accuracy: 0.9379 - marital_accuracy: 0.9521 - val_loss: 0.2574 - val_income_loss: 0.1500 - val_marital_loss: 0.1074 - val_income_accuracy: 0.9378 - val_marital_accuracy: 0.
# 6236/6236 [==============================] - 8s 1ms/step - loss: 0.2326 - income_loss: 0.1333 - marital_loss: 0.0993 - income_accuracy: 0.9464 - marital_accuracy: 0.9562 - val_loss: 0.2244 - val_income_loss: 0.1288 - val_marital_loss: 0.0956 - val_income_accuracy: 0.9499 - val_marital_accuracy: 0.9569
# income-AUC: Train-0.9379, Eval-0.9393, Test-0.9379
# marital-AUC: Train-0.9941, Eval-0.9940, Test-0.9936
# Epoch 34/100
# 6236/6236 [==============================] - 8s 1ms/step - loss: 0.2296 - income_loss: 0.1309 - marital_loss: 0.0987 - income_accuracy: 0.9486 - marital_accuracy: 0.9564 - val_loss: 0.2288 - val_income_loss: 0.1299 - val_marital_loss: 0.0989 - val_income_accuracy: 0.9485 - val_marital_accuracy: 0.9553
# income-AUC: Train-0.9338, Eval-0.9335, Test-0.9332
# marital-AUC: Train-0.9940, Eval-0.9938, Test-0.9935
# Epoch 35/100
# 6236/6236 [==============================] - 7s 1ms/step - loss: 0.2305 - income_loss: 0.1322 - marital_loss: 0.0983 - income_accuracy: 0.9475 - marital_accuracy: 0.9568 - val_loss: 0.2290 - val_income_loss: 0.1261 - val_marital_loss: 0.1029 - val_income_accuracy: 0.9508 - val_marital_accuracy: 0.9567
# income-AUC: Train-0.9365, Eval-0.9367, Test-0.9358
# marital-AUC: Train-0.9933, Eval-0.9933, Test-0.9928
# Epoch 36/100
# 6236/6236 [==============================] - 11s 2ms/step - loss: 0.2286 - income_loss: 0.1302 - marital_loss: 0.0984 - income_accuracy: 0.9486 - marital_accuracy: 0.9564 - val_loss: 0.2386 - val_income_loss: 0.1394 - val_marital_loss: 0.0992 - val_income_accuracy: 0.9391 - val_marital_accuracy: 0.9567
# income-AUC: Train-0.9300, Eval-0.9311, Test-0.9302
# marital-AUC: Train-0.9938, Eval-0.9936, Test-0.9933
# Epoch 37/100
# 6236/6236 [==============================] - 8s 1ms/step - loss: 0.2310 - income_loss: 0.1318 - marital_loss: 0.0992 - income_accuracy: 0.9473 - marital_accuracy: 0.9559 - val_loss: 0.2272 - val_income_loss: 0.1316 - val_marital_loss: 0.0956 - val_income_accuracy: 0.9504 - val_marital_accuracy: 0.9570
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py:106, in normalize_element(element, element_signature)
#     105   if spec is None:
# --> 106     spec = type_spec_from_value(t, use_fallback=False)
#     107 except TypeError:
#     108   # TypeError indicates it was not possible to compute a `TypeSpec` for
#     109   # the value. As a fallback try converting the value to a tensor.
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py:486, in type_spec_from_value(element, use_fallback)
#     483     logging.vlog(
#     484         3, "Failed to convert %r to tensor: %s" % (type(element).__name__, e))
# --> 486 raise TypeError("Could not build a TypeSpec for %r with type %s" %
#     487                 (element, type(element).__name__))
#
# TypeError: Could not build a TypeSpec for         age  wage_per_hour  capital_gains  capital_losses  stock_dividends  \
# 267591   44              0              0               0              250
# 263206   15              0              0               0                0
# 267237   38              0              0               0              300
# 226213   28              0              0               0                0
# 229039   36              0              0               0               10
# ...     ...            ...            ...             ...              ...
# 248774   61              0              0               0                0
# 214877   44              0              0               0                0
# 261068   46            900              0               0                0
# 284162   65              0              0               0                0
# 291709   52              0              0               0                0
#
#         instance_weight  num_emp  own_or_self  vet_benefits  weeks_worked  \
# 267591          1056.89        4            0             2            52
# 263206          1377.84        1            0             2             5
# 267237          1678.95        6            2             2            52
# 226213           996.81        1            0             2            52
# 229039          1164.63        6            0             2            52
# ...                 ...      ...          ...           ...           ...
# 248774          1742.95        0            0             2             0
# 214877          1240.99        4            0             2            40
# 261068          1066.44        3            2             2            22
# 284162          1952.93        0            0             2             0
# 291709          1760.21        3            0             2            52
#
#         ...  country_self_ Vietnam  country_self_ Yugoslavia  \
# 267591  ...                      0                         0
# 263206  ...                      0                         0
# 267237  ...                      0                         0
# 226213  ...                      0                         0
# 229039  ...                      0                         0
# ...     ...                    ...                       ...
# 248774  ...                      0                         0
# 214877  ...                      0                         0
# 261068  ...                      0                         0
# 284162  ...                      0                         0
# 291709  ...                      0                         0
#
#         citizenship_ Foreign born- Not a citizen of U S   \
# 267591                                                 0
# 263206                                                 0
# 267237                                                 0
# 226213                                                 1
# 229039                                                 0
# ...                                                  ...
# 248774                                                 1
# 214877                                                 0
# 261068                                                 1
# 284162                                                 0
# 291709                                                 0
#
#         citizenship_ Foreign born- U S citizen by naturalization  \
# 267591                                                  0
# 263206                                                  0
# 267237                                                  0
# 226213                                                  0
# 229039                                                  0
# ...                                                   ...
# 248774                                                  0
# 214877                                                  0
# 261068                                                  0
# 284162                                                  0
# 291709                                                  0
#
#         citizenship_ Native- Born abroad of American Parent(s)  \
# 267591                                                  0
# 263206                                                  0
# 267237                                                  0
# 226213                                                  0
# 229039                                                  0
# ...                                                   ...
# 248774                                                  0
# 214877                                                  0
# 261068                                                  0
# 284162                                                  0
# 291709                                                  0
#
#         citizenship_ Native- Born in Puerto Rico or U S Outlying  \
# 267591                                                  0
# 263206                                                  0
# 267237                                                  0
# 226213                                                  0
# 229039                                                  0
# ...                                                   ...
# 248774                                                  0
# 214877                                                  0
# 261068                                                  0
# 284162                                                  0
# 291709                                                  0
#
#         citizenship_ Native- Born in the United States  vet_question_ No  \
# 267591                                               1                 0
# 263206                                               1                 0
# 267237                                               1                 0
# 226213                                               0                 0
# 229039                                               1                 0
# ...                                                ...               ...
# 248774                                               0                 0
# 214877                                               1                 0
# 261068                                               0                 0
# 284162                                               1                 0
# 291709                                               1                 0
#
#         vet_question_ Not in universe  vet_question_ Yes
# 267591                              1                  0
# 263206                              1                  0
# 267237                              1                  0
# 226213                              1                  0
# 229039                              1                  0
# ...                               ...                ...
# 248774                              1                  0
# 214877                              1                  0
# 261068                              1                  0
# 284162                              1                  0
# 291709                              1                  0
#
# [49881 rows x 499 columns] with type DataFrame
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 5
#       1 auc_callback = ROCCallback(training_data=(train_X, train_labels),
#       2                            validation_data=(val_X, val_labels),
#       3                            test_data=(test_X, test_labels))
# ----> 5 model.fit(x=train_X, y=train_labels, validation_data=(val_X, val_labels), callbacks=[auc_callback], epochs=100)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/keras/engine/training.py:1230, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1227   val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1228   epoch_logs.update(val_logs)
# -> 1230 callbacks.on_epoch_end(epoch, epoch_logs)
#    1231 training_logs = epoch_logs
#    1232 if self.stop_training:
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/keras/callbacks.py:413, in CallbackList.on_epoch_end(self, epoch, logs)
#     411 logs = self._process_logs(logs)
#     412 for callback in self.callbacks:
# --> 413   callback.on_epoch_end(epoch, logs)
#
# Cell In[40], line 20, in ROCCallback.on_epoch_end(self, epoch, logs)
#      18 def on_epoch_end(self, epoch, logs={}):
#      19     train_pred = self.model.predict(self.train_X)
# ---> 20     val_pred = self.model.predict(self.val_X)
#      21     test_pred = self.model.predict(self.test_X)
#      23     # Iterate through each task and output their ROC-AUC across different datasets
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/keras/engine/training.py:1720, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1714   except ValueError:
#    1715     warnings.warn('Using Model.predict with '
#    1716                   'MultiWorkerDistributionStrategy or TPUStrategy and '
#    1717                   'AutoShardPolicy.FILE might lead to out-of-order result'
#    1718                   '. Consider setting it to AutoShardPolicy.DATA.')
# -> 1720 data_handler = data_adapter.get_data_handler(
#    1721     x=x,
#    1722     batch_size=batch_size,
#    1723     steps_per_epoch=steps,
#    1724     initial_epoch=0,
#    1725     epochs=1,
#    1726     max_queue_size=max_queue_size,
#    1727     workers=workers,
#    1728     use_multiprocessing=use_multiprocessing,
#    1729     model=self,
#    1730     steps_per_execution=self._steps_per_execution)
#    1732 # Container that configures and calls `tf.keras.Callback`s.
#    1733 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/keras/engine/data_adapter.py:1383, in get_data_handler(*args, **kwargs)
#    1381 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383 return DataHandler(*args, **kwargs)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/keras/engine/data_adapter.py:1138, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1135   self._steps_per_execution_value = steps_per_execution.numpy().item()
#    1137 adapter_cls = select_data_adapter(x, y)
# -> 1138 self._adapter = adapter_cls(
#    1139     x,
#    1140     y,
#    1141     batch_size=batch_size,
#    1142     steps=steps_per_epoch,
#    1143     epochs=epochs - initial_epoch,
#    1144     sample_weights=sample_weight,
#    1145     shuffle=shuffle,
#    1146     max_queue_size=max_queue_size,
#    1147     workers=workers,
#    1148     use_multiprocessing=use_multiprocessing,
#    1149     distribution_strategy=tf.distribute.get_strategy(),
#    1150     model=model)
#    1152 strategy = tf.distribute.get_strategy()
#    1154 self._current_step = 0
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/keras/engine/data_adapter.py:322, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     318   return flat_dataset
#     320 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
# --> 322 dataset = self.slice_inputs(indices_dataset, inputs)
#     324 if shuffle == "batch":
#     325   def shuffle_batch(*batch):
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/keras/engine/data_adapter.py:348, in TensorLikeDataAdapter.slice_inputs(self, indices_dataset, inputs)
#     331 def slice_inputs(self, indices_dataset, inputs):
#     332   """Slice inputs into a Dataset of batches.
#     333
#     334   Given a Dataset of batch indices and the unsliced inputs,
#    (...)
#     344     A Dataset of input batches matching the batch indices.
#     345   """
#     346   dataset = tf.data.Dataset.zip((
#     347       indices_dataset,
# --> 348       tf.data.Dataset.from_tensors(inputs).repeat()
#     349   ))
#     351   def grab_batch(i, data):
#     352     return tf.nest.map_structure(lambda d: tf.gather(d, i, axis=0), data)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:606, in DatasetV2.from_tensors(tensors)
#     570 @staticmethod
#     571 def from_tensors(tensors):
#     572   """Creates a `Dataset` with a single element, comprising the given tensors.
#     573
#     574   `from_tensors` produces a dataset containing only a single element. To slice
#    (...)
#     604     Dataset: A `Dataset`.
#     605   """
# --> 606   return TensorDataset(tensors)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py:3825, in TensorDataset.__init__(self, element)
#    3823 def __init__(self, element):
#    3824   """See `Dataset.from_tensors()` for details."""
# -> 3825   element = structure.normalize_element(element)
#    3826   self._structure = structure.type_spec_from_value(element)
#    3827   self._tensors = structure.to_tensor_list(self._structure, element)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py:111, in normalize_element(element, element_signature)
#     106     spec = type_spec_from_value(t, use_fallback=False)
#     107 except TypeError:
#     108   # TypeError indicates it was not possible to compute a `TypeSpec` for
#     109   # the value. As a fallback try converting the value to a tensor.
#     110   normalized_components.append(
# --> 111       ops.convert_to_tensor(t, name="component_%d" % i))
#     112 else:
#     113   if isinstance(spec, sparse_tensor.SparseTensorSpec):
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     161   with Trace(trace_name, **trace_kwargs):
#     162     return func(*args, **kwargs)
# --> 163 return func(*args, **kwargs)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1566, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1561       raise TypeError("convert_to_tensor did not convert to "
#    1562                       "the preferred dtype: %s vs %s " %
#    1563                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1565 if ret is None:
# -> 1566   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1568 if ret is NotImplemented:
#    1569   continue
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py:346, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     343 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     344                                          as_ref=False):
#     345   _ = as_ref
# --> 346   return constant(v, dtype=dtype, name=name)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py:271, in constant(value, dtype, shape, name)
#     174 @tf_export("constant", v1=[])
#     175 def constant(value, dtype=None, shape=None, name="Const"):
#     176   """Creates a constant tensor from a tensor-like object.
#     177
#     178   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py:283, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281     with trace.Trace("tf.constant"):
#     282       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     285 g = ops.get_default_graph()
#     286 tensor_value = attr_value_pb2.AttrValue()
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py:308, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py:106, in convert_to_eager_tensor(value, ctx, dtype)
#     104     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105 ctx.ensure_initialized()
# --> 106 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py:2072, in NDFrame.__array__(self, dtype)
#    2071 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2072     return np.asarray(self._values, dtype=dtype)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:918, in DataFrame._values(self)
#     916 blocks = mgr.blocks
#     917 if len(blocks) != 1:
# --> 918     return self.values
#     920 arr = blocks[0].values
#     921 if arr.ndim == 1:
#     922     # non-2D ExtensionArray
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py:10877, in DataFrame.values(self)
#   10804 """
#   10805 Return a Numpy representation of the DataFrame.
#   10806
#    (...)
#   10874        ['monkey', nan, None]], dtype=object)
#   10875 """
#   10876 self._consolidate_inplace()
# > 10877 return self._mgr.as_array()
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py:1589, in BlockManager.as_array(self, dtype, copy, na_value)
#    1587             arr = arr.astype(dtype, copy=False)
#    1588 else:
# -> 1589     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1590     # The underlying data was copied within _interleave
#    1591     copy = False
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py:1654, in BlockManager._interleave(self, dtype, na_value)
#    1652     else:
#    1653         arr = blk.get_values(dtype)
# -> 1654     result[rl.indexer] = arr
#    1655     itemmask[rl.indexer] = 1
#    1657 if not itemmask.all():
#
# KeyboardInterrupt:
